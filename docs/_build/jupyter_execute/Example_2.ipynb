# %% [markdown]
# # Integrate pygcc with GWB

# %% [markdown]
# #### Import pygcc, GWBplugin and other modules

# %%
import sys, pygcc, pandas as pd
from pygcc.pygcc_utils import *
# print(pygcc.__version__)

# %%
# load GWB plugin
sys.path.append("c:/program files/gwb/src")
sys.path.append(os.path.abspath('.'))

# import GWBplugin class
from GWBplugin import *

# create the plug-in object
myGWBrun = GWBplugin()

from output_reader import read_gwboutput

# %% [markdown]
# #### Load filtered vent fluid data
# This example is from Syverson, D. D., Awolayo, D., & Tutolo, B. M. (2021). Global constraints on secular changes in mid-ocean ridge subseafloor sulfide deposition and metal fluxes through Earth history. In AGU Fall Meeting 2021. AGU.
#
# Here we will work with EPR 21 N sample to run speciation and warm up the fluid from 25 °C to 355 °C

# %%
filename = './MARHYS_DB_2_0_filter.csv'
df = pd.read_csv(filename)
i = 1    
df.loc[1,:]
# Out:
# Sample-ID                        EPR 21°N-SW-1981
# Geol_setting         Mid-oceanic spreading center
# Rock_type_primary                          Basalt
# Depth                                        2500
# Temp                                          355
# pH                                            3.6
# XH2S                                         7.45
# Cl                                          496.0
# Na                                          439.0
# Fe                                            750
# Mn                                            699
# H2                                           0.01
# K                                            23.2
# Ca                                           16.6
# Si                                           17.3
# Cu                                            9.7
# Press                                  251.945325
# Name: 1, dtype: object

# %% [markdown]
# #### Automate the generation of database for each vent fluid with pygcc and run speciation with gwb React
# The gwb output files are stored in the folder 'Ventspec'

# %%
T = [20, df.loc[i,:].Temp]
P = np.round(df.loc[i,:].Press)*np.ones(np.size(T))
Temp = df.loc[i,:].Temp;       npH = df.loc[i,:].pH
nCl = df.loc[i,:].Cl;          nNa = df.loc[i,:].Na
nH2S = df.loc[i,:].XH2S;       nFe = df.loc[i,:].Fe
nMn = df.loc[i,:].Mn;          nH2 = df.loc[i,:].H2
nK = df.loc[i,:].K;            nCu = df.loc[i,:].Cu;    
nCa = df.loc[i,:].Ca;          nSi = df.loc[i,:].Si
objdbname = './thermo.%sbars%sC' % (int(P[0]), int(df.loc[i,:].Temp))
write_database(T = [20, Temp], P = P, solid_solution = True, objdb = objdbname, 
               clay_thermo = 'Yes', dataset = 'GWB',  sourcedb =  './database/thermo.com.tdat')

output_folder = 'Vent_spec'
if os.path.exists(os.path.join(os.getcwd(), output_folder)) == False:
    os.makedirs(os.path.join(os.getcwd(), output_folder))

# start the GWB program
if myGWBrun.initialize("react","%s/runs_%s.txt" % (output_folder, i), 
                       "-nocd -d \"./output/%s.dat\" " % objdbname[1:]):

    cmds = ['H2O  = 1 free kg', 'Fe++  = %s umol/kg' % nFe, "Na+  = %s mmol/kg" % nNa, 
            'pH = %s' % npH, "Cl- = %s mmol/kg" % nCl, "swap H2S(aq) for SO4--", 
            "H2S(aq) = %s mmol/kg" % nH2S, 'Mn++  = %s umol/kg' % nMn, "K+  = %s mmol/kg" % nK, 
            'Ca++  = %s mmol/kg' % nCa, 'SiO2(aq) = %s mmol/kg' % nSi, 'Cu++  = %s umol/kg' % nCu, 
            'temperature initial = 25 C, final = %s C' % Temp, 'swap H2(aq) for O2(aq)', 
            "H2(aq) = %s umol/kg" % nH2,  "balance off"]

    cmds += ['suppress ALL', "plot = character", 'itmax = 9999', "go", 
             'save %s/react%s.rea' % (output_folder, i)]

    for cmd in cmds: 
        myGWBrun.exec_cmd(cmd)

    for fname in os.listdir('./%s' % output_folder):
        if fname.startswith('React_%s.txt' % i):
            os.remove('%s/React_%s.txt' % (output_folder, i))
        if fname.startswith('React_%s.gtp' % i): 
            os.remove('%s/React_%s.gtp' % (output_folder, i))

    os.rename('React_output.txt', '%s/React_%s.txt' % (output_folder, i))
    os.rename('React_plot.gtp', '%s/React_%s.gtp' % (output_folder, i))

print("\nFinished run." )
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\pygcc_utils.py:2266: UserWarning: Some temperature and pressure points are out of aqueous species HKF eqns regions of applicability, hence, density extrapolation has been applied
#   warnings.warn('Some temperature and pressure points are out of aqueous species HKF eqns regions of applicability, hence, density extrapolation has been applied')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-30b3d0ef0c76> in <module>
#       9 objdbname = './thermo.%sbars%sC' % (int(P[0]), int(df.loc[i,:].Temp))
#      10 write_database(T = [20, Temp], P = P, solid_solution = True, objdb = objdbname,
# ---> 11                clay_thermo = 'Yes', dataset = 'GWB',  sourcedb =  './database/thermo.com.tdat')
#      12
#      13 output_folder = 'Vent_spec'
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\pygcc_utils.py in __init__(self, **kwargs)
#    1501     def __init__(self, **kwargs):
#    1502         self.kwargs = write_database.kwargs.copy()
# -> 1503         self.__calc__(**kwargs)
#    1504
#    1505     def __calc__(self, **kwargs):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\pygcc_utils.py in __calc__(self, **kwargs)
#    1595
#    1596         if self.dataset.upper() == 'GWB':
# -> 1597             self.write_GWBdb(self.T, self.P)
#    1598         elif self.dataset.upper() == 'EQ36':
#    1599             self.write_EQ36db(self.T, self.P )
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\pygcc_utils.py in write_GWBdb(self, T, P)
#    2335                                    specielist = specielist, Dielec_method = Dielec_method, rhoEG = rhoEG,
#    2336                                    sourceformat = sourceformat, densityextrap = densityextrap, Specie_class = 'aqueous',
# -> 2337                                    rhoEGextrap = rhoEGextrap).logK
#    2338                 logK = np.where(np.isnan(logK), 500, logK) # set abitrary 500 to nan values
#    2339                 if sourceformat.upper() == 'EQ36' and 'O2(g)' in Rxn:
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\pygcc_utils.py in __init__(self, **kwargs)
#     939     def __init__(self, **kwargs):
#     940         self.kwargs = calcRxnlogK.kwargs.copy()
# --> 941         self.__calc__(**kwargs)
#     942
#     943     def __calc__(self, **kwargs):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\pygcc_utils.py in __calc__(self, **kwargs)
#    1022             if any(subBornptrs):
#    1023                 self.logK[subBornptrs] =  self.densitylogKextrap( self.TC[subBornptrs], self.P[subBornptrs],
# -> 1024                                                                  self.rhoEGextrap)
#    1025             if any(nonsubBornptrs):
#    1026                 if self.Specie.lower().startswith(('plagio', 'oliv', 'pyroxe', 'alk-')) or self.Specie.lower() in ['cpx', 'clay']:
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\pygcc_utils.py in densitylogKextrap(self, TC, P, rhoEGextrap)
#    1203         logK = np.nan*np.ones(np.size(TC))
#    1204         for i in range(length): #need a for loop because calculation is T-specific
# -> 1205             rhotarget =  iapws95(T = TC[i], P = P[i]).rho
#    1206             rhotarget = rhotarget/1000     # kg/m3 => g/cm^3
#    1207             Pextrap = rhoEGextrap['%d_%d' % (TC[i], P[i])]['Pextrap']
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\water_eos.py in __init__(self, **kwargs)
#    1967         self.kwargs = iapws95.kwargs.copy()
#    1968         self.__checker__(**kwargs)
# -> 1969         self.__calc__(**kwargs)
#    1970
#    1971     def __checker__(self, **kwargs):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\water_eos.py in __calc__(self, **kwargs)
#    2053         self.msg = 'Temperature and Pressure input limits: -22 ≤ TC ≤ 1000 and 0 ≤ P ≤ 100,000'
#    2054         if self.mode == "T_P":
# -> 2055             water = Dummy().calcwaterppt(self.TC, self.P, self.rho0, FullEOSppt = self.FullEOSppt)
#    2056             if self.FullEOSppt is True:
#    2057                 [self.rho, self.G, self.H, self.S, self.V, self.P, self.TC, self.U, self.F, self.Cp] = water
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\water_eos.py in calcwaterppt(self, TC, P, FullEOSppt, *rho0)
#    1637         #                   bracket=[0.01, 1e4], x0 = 0.01, x1 = 1e4, xtol = btxtol).root
#    1638         #rho = brentq(funct_tsat, 0.01, 1e4, xtol=btxtol)
# -> 1639         rho = fsolve(funct_tsat, rho)
#    1640         #rho = newton(funct_tsat, rho, fprime = None, args=(), tol=btxtol, maxiter=itermx, fprime2 = None)
#    1641
#
# D:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#     158                'diag': diag}
#     159
# --> 160     res = _root_hybr(func, x0, args, jac=fprime, **options)
#     161     if full_output:
#     162         x = res['x']
#
# D:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     236             maxfev = 200 * (n + 1)
#     237         retval = _minpack._hybrd(func, x0, args, 1, xtol, maxfev,
# --> 238                                  ml, mu, epsfcn, factor, diag)
#     239     else:
#     240         _check_func('fsolve', 'fprime', Dfun, x0, args, n, (n, n))
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\water_eos.py in <lambda>(rho)
#    1633                 rho[i] = 4*rhoc
#    1634
# -> 1635         funct_tsat = lambda rho: self.vEOSIAPWS95(TK, rho, FullEOSppt = FullEOSppt)[0]*0.1 - P*0.1
#    1636         # rho = root_scalar(funct_tsat, method = 'secant',
#    1637         #                   bracket=[0.01, 1e4], x0 = 0.01, x1 = 1e4, xtol = btxtol).root
#
# D:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    2161             vargs.extend([kwargs[_n] for _n in names])
#    2162
# -> 2163         return self._vectorize_call(func=func, args=vargs)
#    2164
#    2165     def _get_ufunc_and_otypes(self, func, args):
#
# D:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2244             inputs = [asanyarray(a, dtype=object) for a in args]
#    2245
# -> 2246             outputs = ufunc(*inputs)
#    2247
#    2248             if ufunc.nout == 1:
#
# D:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in func(*vargs)
#    2156                     the_args[_i] = vargs[_n]
#    2157                 kwargs.update(zip(names, vargs[len(inds):]))
# -> 2158                 return self.pyfunc(*the_args, **kwargs)
#    2159
#    2160             vargs = [args[_i] for _i in inds]
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\water_eos.py in EOSIAPWS95(self, TK, rho, FullEOSppt)
#     775
#     776         # Pressure kpa to bar.
# --> 777         px = rho*R*TK*( 1 + delta*phir_d(delta, tau) ) * 0.010
#     778
#     779         # Internal energy. kJ/kg
#
# D:\ProgramData\Anaconda3\lib\site-packages\pygcc\water_eos.py in phir_d(delta, tau)
#     372             y = y + np.dot(n[51:54], (delta**d[51:54] * tau**t[51:54] \
#     373                                       * np.exp(-alpha*(delta - epsilon)**2 - beta[:3]*(tau - gamma)**2) \
# --> 374                                           * (d[51:54]/delta - 2*alpha*(delta - epsilon))))
#     375
#     376             tPsi = Psi(delta,tau)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Extract simulation results

# %%
rerun = []
path = './' + output_folder + '/'
files = os.listdir(path)
for i, f in enumerate(files):
    if f.endswith('.gtp') and f.startswith('React_'): 
        size = os.path.getsize(path + f)/(1024) #size in KB
        if size > 2:
            data = read_gwboutput(path + f)
        else:
            rerun.append(f)
print(rerun)

# %%
# data

# %% [markdown]
# Plot pyrite saturation with temperature

# %%
import matplotlib.pyplot as plt
y = data.SI_Pyrite
x = data.Temperature
plt.figure()
plt.scatter(x, y)
plt.plot([0, 350], [0, 0], 'k--')
plt.xlim([0, 350])
plt.xlabel('Temperature [C]')
plt.ylabel('$Log_{10}$(Q/K)$_{Pyrite}$')

# %% [markdown]
# pH versus temperature

# %%
y = data.pH
x = data.Temperature
plt.figure()
sc = plt.scatter(x, y)
plt.xlim([0, 350])
plt.xlabel('Temperature [C]')
plt.ylabel('pH')
